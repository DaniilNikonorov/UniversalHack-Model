# %%
import recbole
import pandas as pd

# %%
pd.read_table("../content/supermarket_train.tsv")
# Out:
#               device_id   receipt_id  item_id          server_date  \
# 0       352398080550058  13014665572   104821  2022-10-16 14:38:00
# 1       352398080550058  13014665572   107726  2022-10-16 14:38:00
# 2       352398080550058  13014716101   100671  2022-10-16 14:42:06
# 3       352398080550058  13014716101   104645  2022-10-16 14:42:06
# 4       352398080550058  13015069818   107708  2022-10-16 15:11:39
# ...                 ...          ...      ...                  ...
# 696782  352398080043187  10117495751   101631  2021-12-15 12:49:21
# 696783  352398080043187  10117495751   101633  2021-12-15 12:49:21
# 696784  352398080043187  10117495751   111409  2021-12-15 12:49:21
# 696785  352398080043187  10117495751   100619  2021-12-15 12:49:21
# 696786  352398080043187  10117495751   100328  2021-12-15 12:49:21
#
#                  local_date  \
# 0       2022-10-16 14:38:01
# 1       2022-10-16 14:38:01
# 2       2022-10-16 14:42:06
# 3       2022-10-16 14:42:06
# 4       2022-10-16 15:11:39
# ...                     ...
# 696782  2021-12-15 12:49:19
# 696783  2021-12-15 12:49:19
# 696784  2021-12-15 12:49:19
# 696785  2021-12-15 12:49:19
# 696786  2021-12-15 12:49:19
#
#                                                      name  price  quantity  \
# 0                         Картофель /новый урожай/Россия/   31.9     28.45
# 1       Молоко Станичное 3.2% 1.0л ультрапастеризованн...   89.0      1.00
# 2                    Вафли Коламбина /телевизор/Кузнецов/  367.0      2.00
# 3       К-ты Хо-хо-чу глаз.солен.карамель /Невск.конди...  334.0      1.00
# 4       Молоко Молочный гостинец 3.2% 930гр ультрапаст...   89.0      1.00
# ...                                                   ...    ...       ...
# 696782                   Газета Курьер Псков-Великие Луки   26.0      1.00
# 696783                                  Газета Стерх-Луки   51.0      1.00
# 696784  Пирожное бискв.с масл.кремом 80гр /ПО Переслег...   37.0      4.00
# 696785  Ватрушка с творогом сдобная 140гр м/уп. /Пореч...   39.5      1.00
# 696786      Батон нарезной 300гр нарезка /Куньинский х/з/   35.0      1.00
#
#         my_ckecker
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 696782         NaN
# 696783         NaN
# 696784         NaN
# 696785         NaN
# 696786         NaN
#
# [696787 rows x 9 columns]

# %%
interactions_df.to_csv(f'content/.inter', sep='\t',
                               index=False, header=['user_id:token', 'item_id:token',
                                                    'rating:float', 'timestamp:float'], float_format='%d')

# %%
list({'f':3, 'k':4}.keys())[:1]
# Out:
# ['f']
